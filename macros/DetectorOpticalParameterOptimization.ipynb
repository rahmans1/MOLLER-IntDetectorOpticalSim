# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmans1/MOLLER-IntDetectorOpticalSim/blob/feature-addJobSubmissionScript/macros/DetectorOpticalParameterOptimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring4/Run1_Ring4_Quartz.txt")
df2=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring4/Run2_Ring4_Quartz.txt")
df3=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring4/Run3_Ring4_Quartz.txt")
df4=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring4/Run4_Ring4_Quartz.txt")
df= pd.concat([df1,df2, df3, df4], axis=0)
print(df.keys())
import plotly.express as px

fig = px.scatter_3d(df, x='LowerConeFrontFaceAngle', y='LowerConeBackFaceAngle', z= 'QuartzToPMTOffsetInZ', size='ExNoise',
                 color='Mean',  hover_data=['Mean', 'ExNoise'])
fig.show()

fig = px.scatter(df, x='LowerConeFrontFaceAngle', y='LowerConeBackFaceAngle', size='ExNoise',
                 color='Mean',  hover_data=['QuartzToPMTOffsetInZ','Mean', 'ExNoise'])
fig.show()

fig = px.scatter(df, x='LowerConeFrontFaceAngle', y='QuartzToPMTOffsetInZ', size='ExNoise',
                 color='Mean',  hover_data=['LowerConeFrontFaceAngle', 'Mean', 'ExNoise'])
fig.show()
# Out:
# Index(['QuartzSizeX', 'QuartzSizeY', 'QuartzSizeZ', 'LowerInterfacePlane',
#        'UpperInterfacePlane', 'LowerConeFrontFaceAngle',
#        'LowerConeBackFaceAngle', 'LowerConeSideFaceAngle',
#        'QuartzInterfaceOpeningZ', 'QuartzInterfaceOpeningX',
#        'PMTInterfaceOpeningZ', 'PMTInterfaceOpeningX', 'QuartzToPMTOffsetInZ',
#        'QuartzBevel', 'QuartzRotation', 'DetectorRotation', 'HitRegion',
#        'Mean', 'ExNoise'],
#       dtype='object')
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring2/Quartz/Run4_Ring2_Quartz.txt")
df2=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring2/Quartz/Run5_Ring2_Quartz.txt")

df= pd.concat([df1,df2], axis=0)
print(df.keys())
import plotly.express as px

fig = px.scatter_3d(df, x='LowerConeFrontFaceAngle', y='LowerConeBackFaceAngle', z= 'QuartzToPMTOffsetInZ', size='ExNoise',
                 color='Mean',  hover_data=['Mean', 'ExNoise'])
fig.show()

fig = px.scatter(df, x='LowerConeFrontFaceAngle', y='LowerConeBackFaceAngle', size='ExNoise',
                 color='Mean',  hover_data=['QuartzToPMTOffsetInZ','Mean', 'ExNoise'])
fig.show()

fig = px.scatter(df, x='LowerConeFrontFaceAngle', y='QuartzToPMTOffsetInZ', size='ExNoise',
                 color='Mean',  hover_data=['LowerConeFrontFaceAngle', 'Mean', 'ExNoise'])
fig.show()
# Out:
# Index(['QuartzSizeX', 'QuartzSizeY', 'QuartzSizeZ', 'LowerInterfacePlane',
#        'UpperInterfacePlane', 'LowerConeFrontFaceAngle',
#        'LowerConeBackFaceAngle', 'LowerConeSideFaceAngle',
#        'QuartzInterfaceOpeningZ', 'QuartzInterfaceOpeningX',
#        'PMTInterfaceOpeningZ', 'PMTInterfaceOpeningX', 'QuartzToPMTOffsetInZ',
#        'QuartzBevel', 'QuartzRotation', 'DetectorRotation', 'HitRegion',
#        'Mean', 'ExNoise'],
#       dtype='object')
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring2/OpenScienceGrid/Quartz/MOLLEROptRun1_Ring2_Quartz.txt")
df.columns= ['QuartzSizeX', 'QuartzSizeY', 'QuartzSizeZ', 'LowerInterfacePlane',
       'UpperInterfacePlane', 'LowerConeFrontFaceAngle',
       'LowerConeBackFaceAngle', 'LowerConeSideFaceAngle',
       'QuartzInterfaceOpeningZ', 'QuartzInterfaceOpeningX',
       'PMTInterfaceOpeningZ', 'PMTInterfaceOpeningX', 'QuartzToPMTOffsetInZ',
       'QuartzBevel', 'QuartzRotation', 'DetectorRotation', 'HitRegion',
       'Mean', 'ExNoise'] 
#df2=pd.read_csv("/content/drive/MyDrive/MOLLER/MainDetectorOptimization/ring2/Quartz/Run5_Ring2_Quartz.txt")

#df= pd.concat([df1,df2], axis=0)
print(df.keys())
import plotly.express as px

fig = px.scatter_3d(df, x='LowerConeFrontFaceAngle', y='LowerConeBackFaceAngle', z= 'QuartzToPMTOffsetInZ', size='ExNoise',
                 color='Mean',  hover_data=['Mean', 'ExNoise'])
fig.show()

fig = px.scatter(df, x='LowerConeFrontFaceAngle', y='LowerConeBackFaceAngle', size='ExNoise',
                 color='Mean',  hover_data=['QuartzToPMTOffsetInZ','Mean', 'ExNoise'])
fig.show()

fig = px.scatter(df, x='LowerConeFrontFaceAngle', y='QuartzToPMTOffsetInZ', size='ExNoise',
                 color='Mean',  hover_data=['LowerConeFrontFaceAngle', 'Mean', 'ExNoise'])
fig.show()
# Out:
# Index(['QuartzSizeX', 'QuartzSizeY', 'QuartzSizeZ', 'LowerInterfacePlane',
#        'UpperInterfacePlane', 'LowerConeFrontFaceAngle',
#        'LowerConeBackFaceAngle', 'LowerConeSideFaceAngle',
#        'QuartzInterfaceOpeningZ', 'QuartzInterfaceOpeningX',
#        'PMTInterfaceOpeningZ', 'PMTInterfaceOpeningX', 'QuartzToPMTOffsetInZ',
#        'QuartzBevel', 'QuartzRotation', 'DetectorRotation', 'HitRegion',
#        'Mean', 'ExNoise'],
#       dtype='object')
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
